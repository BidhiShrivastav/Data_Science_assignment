# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)


df = load_dataset("./Health_heart_experimental.csv")
df.head(5)
# Out:
#    Unnamed: 0  age  sex  SysBP  DiaBP   HR  weightKg  heightCm   BMI  \
# 0           0   64    1    141     96  128        69       147  32.0
# 1           1   21    1    109    100  106        48       150  21.0
# 2           2   30    0    112     73  126        69       183  21.0
# 3           3   35    1    106     90  130        45       149  20.0
# 4           4   39    0    140     90  112        92       166  33.0
#
#    indication
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1

# %% [markdown]
# # LINE CHART

# %%
age = [64, 21, 30, 35, 39,42,60,45,50,41]
bmi = [32.0,21.0,21.0,20.0,33.0,29.0,19.0,23.0,27.0,18.0]

# create a line chart, years on x-axis, gdp on y-axis
plt.plot(age, bmi, color='pink', marker='o', linestyle='dotted')

# add a title
plt.title("health evaluation")

# add a label to the y-axisYears
plt.ylabel("range")
plt.xlabel(" age category")
plt.show()

# %% [markdown]
# # BAR PLOT

# %%
age = [64, 21, 30, 35, 39,42,60,45,50,41]
DiaBp = [96,100,73,90,90,120,84,93,65,40]

plt.bar(range(len(age)), DiaBp, color='pink')

plt.title("DiaBp category according to age")
plt.ylabel("DiaBp")
plt.xlabel("age")

plt.xticks(range(len(age)), age)

plt.show()

# %% [markdown]
# # PIE CHART

# %%
sex=[1, 1, 0, 1, 0, 1, 0, 0, 1,0]
df = pd.DataFrame(data)

df['sex'].value_counts().plot(kind='pie', autopct='%0.2f', labels=['Male', 'Female'],colors=['lightgreen', 'pink'])
plt.title('Sex division')
plt.show()

# %% [markdown]
# # BOX PLOT

# %% [markdown]
# # HISTOGRAM

# %%
bmi = [32.0,21.0,21.0,20.0,33.0,29.0,19.0,23.0,27.0,18.0]
plt.hist(df['bmi'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Rahil\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bmi'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 2
# ...

# %%
age = [64, 21, 30, 35, 39,42,60,45,50,41]
plt.hist(df['age'])
# Out:
# (array([2., 1., 2., 1., 0., 0., 1., 0., 0., 2.]),
#  array([21. , 25.7, 30.4, 35.1, 39.8, 44.5, 49.2, 53.9, 58.6, 63.3, 68. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # BOX PLOT

# %%
# boxplot
age = [64, 21, 30, 35, 39,42,60,45,50,41]
df = pd.DataFrame(data)

sns.boxplot(df['age'])
plt.title('Boxplot of Age')
plt.xlabel('Age')
plt.ylabel("")
plt.show()

# %%
age = [64, 21, 30, 35, 39,42,60,45,50,41]
df = pd.DataFrame(data)

sns.displot(df['age'], kind="hist", kde=True, color='pink')
plt.title('age category')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # scatter plot

# %%
age=[64, 21, 30, 35, 39, 68, 50, 23, 34],
sex=[1, 1, 0, 1, 0, 1, 1, 1, 1]
SysBP=[141, 109, 112, 106, 140, 115, 125, 111, 144],
DiaBP=[96, 100, 73, 90, 90, 93, 117, 85, 80],
HR=[128, 106, 126, 130, 112, 130, 89, 131, 90],
weightKg=[69, 48, 69, 45, 92, 53, 56, 55, 67],
heightCm=[147, 150, 183, 149, 166, 172, 172, 169, 178],
BMI=[32.0, 21.0, 21.0, 20.0, 33.0, 18.0, 19.0, 19.0, 21.0],
indication=[1, 0, 0, 0, 1, 0, 0, 0, 0]

df = pd.DataFrame(data)

print(df)
# Out:
#    age  sex  SysBP  DiaBP   HR  weightKg  heightCm   BMI  indication
# 0   64    1    141     96  128        69       147  32.0           1
# 1   21    1    109    100  106        48       150  21.0           0
# 2   30    0    112     73  126        69       183  21.0           0
# 3   35    1    106     90  130        45       149  20.0           0
# 4   39    0    140     90  112        92       166  33.0           1
# 5   68    1    115     93  130        53       172  18.0           0
# 6   50    1    125    117   89        56       172  19.0           0
# 7   23    1    111     85  131        55       169  19.0           0
# 8   34    1    144     80   90        67       178  21.0           0
